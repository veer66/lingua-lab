# %% [markdown]
# <a href="https://colab.research.google.com/github/veer66/python-for-linguists/blob/main/PyThaiNLP_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://pythainlp.org/tutorials/notebooks/Thai_Dependency_Parser.html

# %%
# !pip install "pythainlp[full]"

# %%
import spacy_thai
nlp=spacy_thai.load()

# %%
doc=nlp("พวกเราใช้ภาษาไทย")

# %%
import graphviz
import deplacy
graphviz.Source(deplacy.dot(doc))

# %% [markdown]
# Word tokenization

# %%
from pythainlp.tokenize import word_tokenize
word_tokenize("ทดสอบตัดคำภาษาไทย")
# Out:
# ['ทดสอบ', 'ตัด', 'คำ', 'ภาษาไทย']
