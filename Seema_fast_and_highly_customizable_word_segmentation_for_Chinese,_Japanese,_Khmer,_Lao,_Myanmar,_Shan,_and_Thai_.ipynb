# %% [markdown]
# <a href="https://colab.research.google.com/github/veer66/python-for-linguists/blob/main/Seema_fast_and_highly_customizable_word_segmentation_for_Chinese%2C_Japanese%2C_Khmer%2C_Lao%2C_Myanmar%2C_Shan%2C_and_Thai_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install seema
# !wget -q https://codeberg.org/mekong-lang/mekong-lang-data/archive/main.tar.gz -O - | tar xzf -
s = Seema("mekong-lang-data/dictionaries/mixed/chamkho-dict.txt", "mekong-lang-data/cluster-rules/thai_cluster_rules.txt")
s.segment_into_strings("វេវចនានុក្រមពហុភាសាដោយឥតគិតថ្លៃฉันกินข้าวຈະຊອກຫາອີ່ຫຍັງ本日のお仕事終了 しましたpop musicရှေး")
# Out:
# Collecting seema
#   Downloading seema-0.3.2.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: seema
#   Building wheel for seema (pyproject.toml) ... done
#   Created wheel for seema: filename=seema-0.3.2-cp312-cp312-linux_x86_64.whl size=1057495 sha256=7c409b33d554789a48494dea2e8cddd3c6932809dbfdde975ec2d6cbbedc7289
#   Stored in directory: /root/.cache/pip/wheels/cf/97/5e/589f051089409760f597feda4a3b728beeb49eccbe3ecd2eea
# Successfully built seema
# Installing collected packages: seema
# Successfully installed seema-0.3.2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3927886331.py in <cell line: 0>()
#       1 get_ipython().system('pip install seema')
#       2 get_ipython().system('wget -q https://codeberg.org/mekong-lang/mekong-lang-data/archive/main.tar.gz -O - | tar xzf -')
# ----> 3 s = Seema("mekong-lang-data/dictionaries/mixed/chamkho-dict.txt", "mekong-lang-data/cluster-rules/thai_cluster_rules.txt")
#       4 s.segment_into_strings("វេវចនានុក្រមពហុភាសាដោយឥតគិតថ្លៃฉันกินข้าวຈະຊອກຫາອີ່ຫຍັງ本日のお仕事終了 しましたpop musicရှေး")
#
# NameError: name 'Seema' is not defined
